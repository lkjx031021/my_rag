# %%
from langchain_ollama import OllamaEmbeddings

OLLAMA_BASE_URL = "http://localhost:11434"
model_name = "bge-m3:latest"

embeddings = OllamaEmbeddings(model=model_name, base_url=OLLAMA_BASE_URL)

input_text = ["今天天气不错，挺风和日丽的"]
vector = embeddings.embed_documents(input_text)
print(vector)
# print(vector.shape)
# Out:
# [[-0.015135917, 0.035136677, -0.06429714, -0.010312662, -0.029387144, -0.055838507, 0.010498779, 0.024836075, 0.01631639, 0.004896708, -0.016396234, 0.0013556558, 0.022159051, -0.0028081054, 0.0018361378, 0.0060582915, 0.052675173, -0.006046601, -0.0010215581, -0.04608019, 0.010602345, 0.012911738, -0.035097502, -0.003733326, -0.036717564, 0.026210766, -0.01049602, -0.0035950541, 0.034546927, 0.044573866, 0.007265339, 0.041731264, 0.015257394, -0.0015152282, -0.021846162, -0.04273953, -0.024059089, -0.016807545, -0.022371674, 0.02960125, 0.044283766, -0.03878732, 0.040830754, 0.0063512656, -0.014374018, -0.04185283, -0.028691929, -0.0019930787, -0.042968903, -0.041845854, 0.03339518, 0.025956264, 0.03138029, -0.018359123, 0.010085159, -0.0048204134, 0.033444006, -0.014591735, -0.06341998, -0.021983856, -0.056764107, 0.000294539, -0.0075651463, 0.004992745, -0.013992502, 0.12517922, 0.012973979, 0.01753073, -0.025715744, -0.030438973, 0.00076898467, 0.011878728, -5.6606706e-05, -0.009
# ...

# %%
from ollama import embed

model = embed(model="bge-m3:latest", input="今天天气不错，挺风和日丽的")
print(model)
print(model.embeddings)
# Out:
# model='bge-m3:latest' created_at=None done=None done_reason=None total_duration=130612200 load_duration=46820200 prompt_eval_count=10 prompt_eval_duration=None eval_count=None eval_duration=None embeddings=[[-0.015135917, 0.035136677, -0.06429714, -0.010312662, -0.029387144, -0.055838507, 0.010498779, 0.024836075, 0.01631639, 0.004896708, -0.016396234, 0.0013556558, 0.022159051, -0.0028081054, 0.0018361378, 0.0060582915, 0.052675173, -0.006046601, -0.0010215581, -0.04608019, 0.010602345, 0.012911738, -0.035097502, -0.003733326, -0.036717564, 0.026210766, -0.01049602, -0.0035950541, 0.034546927, 0.044573866, 0.007265339, 0.041731264, 0.015257394, -0.0015152282, -0.021846162, -0.04273953, -0.024059089, -0.016807545, -0.022371674, 0.02960125, 0.044283766, -0.03878732, 0.040830754, 0.0063512656, -0.014374018, -0.04185283, -0.028691929, -0.0019930787, -0.042968903, -0.041845854, 0.03339518, 0.025956264, 0.03138029, -0.018359123, 0.010085159, -0.0048204134, 0.033444006, -0.014591735, -0.06
# ...

# %%
import aiohttp

async def get_embedding():
    async with aiohttp.ClientSession() as session:
        async with session.post(
            f"{OLLAMA_BASE_URL}/api/embed",
            json={
                "model": model_name,
                "input": input_text  # 使用 input 而不是 prompt
            }
        ) as response:
            result = await response.json()
            # Ollama embed API 返回格式为 {"embeddings": [[...], ...]}
            return result["embeddings"][0]  # 返回第一个向量

# 使用 asyncio 运行异步函数
import asyncio
embedding_result = asyncio.run(get_embedding())
print(embedding_result)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 18
#      16 # 使用 asyncio 运行异步函数
#      17 import asyncio
# ---> 18 embedding_result = asyncio.run(get_embedding())
#      19 print(embedding_result)
#
# File ~/anaconda3/envs/langchain/lib/python3.11/asyncio/runners.py:186, in run(main, debug)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    182     asyncio.run(main())
#     183 """
#     184 if events._get_running_loop() is not None:
#     185     # fail fast with short traceback
# --> 186     raise RuntimeError(
#     187         "asyncio.run() cannot be called from a running event loop")
#     189 with Runner(debug=debug) as runner:
#     190     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
from pathlib import Path

print(Path("base.py").as_posix())
# Out:
# base.py
